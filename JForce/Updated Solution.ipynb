# %% [markdown]
# # Installing mysql-python connector

# %%
# !pip install mysql-connector-python

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import mysql.connector

# %% [markdown]
# # Establish a Connection to MySQL

# %%
conn = mysql.connector.connect(
    host = '127.0.0.1',
    username = 'root',
    password = 'Nik_MySQL2024',
    database = 'jforce'
)

# %% [markdown]
# # Create a Cursor Object

# %%
# A cursor object allows us to create and execute queries
cursor = conn.cursor()

# %% [markdown]
# # Retreive Data stored in an existing database

# %%
cursor.execute("SELECT * FROM CUSTOMERS")

# %%
customers = cursor.fetchall()  #fetching all records from customers

# %%
# iterating through the records fetched and printing them
for row in customers:
    print(row)
# Out:
# (201, 'Ashley Silva', 'F', -47, 'Lake Edwardfort', datetime.date(2021, 1, 19))
# (202, 'Ethan Shannon', 'F', 55, 'Jaredshire', datetime.date(2021, 5, 10))
# (203, 'Colleen Lopez', 'M', 31, 'South Eric', datetime.date(2023, 7, 18))
# (204, 'Sarah Nguyen', 'F', 52, 'South Wendyhaven', datetime.date(2020, 1, 23))
# (205, 'Eric Ruiz', 'M', 61, 'North Mark', datetime.date(2020, 5, 19))
# (206, 'Kristen Kelley', 'F', 23, 'North Lisaport', datetime.date(2022, 12, 13))
# (207, 'Charles Burgess', 'F', 24, 'Port Daniel', datetime.date(2023, 6, 6))
# (208, 'Kristine Murray', 'M', 34, 'Katiebury', datetime.date(2023, 2, 6))
# (209, 'Daniel Carter', 'M', 40, 'New Melissa', datetime.date(2021, 7, 25))
# (210, 'Geoffrey Johnson', 'F', 46, 'Jacquelineview', datetime.date(2021, 9, 26))
# (211, 'Megan Holt', 'M', 53, 'East Jacobmouth', datetime.date(2021, 12, 31))
# (212, 'Miss Sara White', 'F', 40, 'Lake Nicholasshire', datetime.date(2021, 9, 21))
# ...

# %%
# creating a dataframe with respective column names to store the customers data
customers = pd.DataFrame(customers, columns = ['customer_id', 'customer_name', 'gender', 'age', 'city', 'join_date'])

# %%
customers
# Out:
#     customer_id   customer_name gender  age              city   join_date
# 0           201    Ashley Silva      F  -47   Lake Edwardfort  2021-01-19
# 1           202   Ethan Shannon      F   55        Jaredshire  2021-05-10
# 2           203   Colleen Lopez      M   31        South Eric  2023-07-18
# 3           204    Sarah Nguyen      F   52  South Wendyhaven  2020-01-23
# 4           205       Eric Ruiz      M   61        North Mark  2020-05-19
# ..          ...             ...    ...  ...               ...         ...
# 95          296  Amanda Johnson      M   47      Nicholasside  2021-04-01
# 96          297  Jessica Bolton      F   55       Abigailstad  2021-05-20
# 97          298  Amanda Elliott      M   40       West Hailey  2021-01-22
# 98          299     Robert Ball      M  -59        West James  2023-03-21
# 99          300  Stephen Harris      M   42        Sawyertown  2023-03-29
#
# [100 rows x 6 columns]

# %%
cursor.execute("SELECT * FROM SALES")

# %%
sales = cursor.fetchall() #fetching all records from sales

# %%
sales
# Out:
# [(1, 107, 273, 5, Decimal('1000.00'), datetime.date(2024, 9, 1), 'South'),
#  (2, 104, 212, 7, Decimal('700.00'), datetime.date(2024, 5, 31), 'West'),
#  (3, 107, 223, 2, Decimal('400.00'), datetime.date(2024, 3, 19), 'West'),
#  (4, 103, 288, 1, Decimal('240.00'), datetime.date(2024, 2, 21), 'West'),
#  (5, 112, 274, 6, Decimal('600.00'), datetime.date(2024, 5, 5), 'West'),
#  (6, 113, 296, 4, Decimal('100.00'), datetime.date(2024, 12, 20), 'North'),
#  (7, 101, 231, 3, Decimal('750.00'), datetime.date(2024, 9, 9), 'West'),
#  (8, 107, 297, 9, Decimal('1800.00'), datetime.date(2024, 3, 12), 'East'),
#  (9, 101, 232, 4, Decimal('1000.00'), datetime.date(2024, 11, 26), 'South'),
#  (10, 111, 227, 7, Decimal('560.00'), datetime.date(2024, 10, 8), 'South'),
#  (11, 101, 229, 1, Decimal('250.00'), datetime.date(2024, 7, 21), 'North'),
#  (12, 102, 252, 4, Decimal('1200.00'), datetime.date(2024, 3, 3), 'North'),
#  (13, 113, 259, 1, Decimal('25.00'), datetime.date(2024, 9, 27), 'West'),
# ...

# %%
# creating a dataframe with respective column names to store the sales data
sales = pd.DataFrame(sales, columns = ['sale_id', 'product_id', 'customer_id', 'quantity_sold', 'sale_amount', 'sale_date', 'region'])

# %%
sales
# Out:
#      sale_id  product_id  customer_id  quantity_sold sale_amount   sale_date  \
# 0          1         107          273              5     1000.00  2024-09-01
# 1          2         104          212              7      700.00  2024-05-31
# 2          3         107          223              2      400.00  2024-03-19
# 3          4         103          288              1      240.00  2024-02-21
# 4          5         112          274              6      600.00  2024-05-05
# ..       ...         ...          ...            ...         ...         ...
# 295      296         113          292              9      225.00  2024-08-27
# 296      297         114          241              8     1200.00  2024-04-04
# 297      298         102          251              5     1500.00  2024-04-29
# 298      299         112          213              5      500.00  2024-11-06
# 299      300         101          267              5     1250.00  2024-03-13
#
#     region
# 0    South
# 1     West
# ...

# %%
cursor.execute("SELECT * FROM PRODUCTS")

# %%
products = cursor.fetchall() #fetching all records from products table

# %%
products
# Out:
# [(101, 'Laptop', 'Electronics', Decimal('250.00')),
#  (102, 'Smartphone', 'Electronics', Decimal('300.00')),
#  (103, 'Tablet', 'Electronics', Decimal('240.00')),
#  (104, 'Headphones', 'Electronics', Decimal('100.00')),
#  (105, 'Office Chair', 'Furniture', Decimal('400.00')),
#  (106, 'Desk', 'Furniture', Decimal('350.00')),
#  (107, 'Bookshelf', 'Furniture', Decimal('200.00')),
#  (108, 'Dining Table', 'Furniture', Decimal('600.00')),
#  (109, 'T-shirt', 'Clothing', Decimal('20.00')),
#  (110, 'Jeans', 'Clothing', Decimal('50.00')),
#  (111, 'Jacket', 'Clothing', Decimal('80.00')),
#  (112, 'Shoes', 'Clothing', Decimal('100.00')),
#  (113, 'Football', 'Sports', Decimal('25.00')),
#  (114, 'Tennis Racket', 'Sports', Decimal('150.00')),
#  (115, 'Basketball', 'Sports', Decimal('30.00')),
#  (116, 'Gym Bag', 'Sports', Decimal('50.00')),
#  (117, 'Gym Shoes', 'Sports', Decimal('50.00')),
#  (118, 'Laptop Bag', 'Sports', Decimal('50.00'))]

# %%
# creating a dataframe with respective column names to store the products data
products = pd.DataFrame(products, columns = ['product_id', 'product_name', 'category', 'price'])

# %%
products
# Out:
#     product_id   product_name     category   price
# 0          101         Laptop  Electronics  250.00
# 1          102     Smartphone  Electronics  300.00
# 2          103         Tablet  Electronics  240.00
# 3          104     Headphones  Electronics  100.00
# 4          105   Office Chair    Furniture  400.00
# 5          106           Desk    Furniture  350.00
# 6          107      Bookshelf    Furniture  200.00
# 7          108   Dining Table    Furniture  600.00
# 8          109        T-shirt     Clothing   20.00
# 9          110          Jeans     Clothing   50.00
# 10         111         Jacket     Clothing   80.00
# 11         112          Shoes     Clothing  100.00
# 12         113       Football       Sports   25.00
# 13         114  Tennis Racket       Sports  150.00
# 14         115     Basketball       Sports   30.00
# 15         116        Gym Bag       Sports   50.00
# 16         117      Gym Shoes       Sports   50.00
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    18 non-null     int64
#  1   product_name  18 non-null     object
#  2   category      18 non-null     object
#  3   price         18 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 708.0+ bytes

# %%
# converting price column to float
products['price'] = products['price'].astype(float)

# %%
products.dtypes
# Out:
# product_id        int64
# product_name     object
# category         object
# price           float64
# dtype: object

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    100 non-null    int64
#  1   customer_name  100 non-null    object
#  2   gender         100 non-null    object
#  3   age            100 non-null    int64
#  4   city           100 non-null    object
#  5   join_date      100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
customers.head()
# Out:
#    customer_id  customer_name gender  age              city   join_date
# 0          201   Ashley Silva      F  -47   Lake Edwardfort  2021-01-19
# 1          202  Ethan Shannon      F   55        Jaredshire  2021-05-10
# 2          203  Colleen Lopez      M   31        South Eric  2023-07-18
# 3          204   Sarah Nguyen      F   52  South Wendyhaven  2020-01-23
# 4          205      Eric Ruiz      M   61        North Mark  2020-05-19

# %%
# checking unique ages for anomalies
customers['age'].unique()
# Out:
# array([-47,  55,  31,  52,  61,  23,  24,  34,  40,  46,  53,  47,  45,
#         56,  65,  58,  36,  29, -41,  43,  59,  30,  50,  54,  37,  18,
#         38,  27, -52,  32,  33,  41,  64,  28,  35,  19,  62,  22,  42,
#         21,  44, -59], dtype=int64)

# %%
# multiplying ages having negative values with -1 to correct them
customers['age'] = customers['age'].apply(lambda x : x*(-1) if x < 0 else x)

# %%
# checking the value counts of all ages after correction
customers['age'].value_counts()
# Out:
# age
# 55    7
# 47    6
# 23    5
# 40    4
# 18    4
# 29    4
# 56    4
# 59    4
# 31    4
# 34    3
# 53    3
# 45    3
# 58    3
# 61    3
# 33    3
# 52    3
# 30    3
# 54    3
# 46    2
# 21    2
# 42    2
# 19    2
# 35    2
# 37    2
# 50    2
# 43    2
# 41    2
# 36    2
# 24    2
# 38    1
# 27    1
# 32    1
# 64    1
# 28    1
# 62    1
# 22    1
# 65    1
# 44    1
# Name: count, dtype: int64

# %%
# checking gender wise customer counts
customers.groupby('gender')['customer_id'].count()
# Out:
# gender
# F    50
# M    50
# Name: customer_id, dtype: int64

# %%
# using value-counts to check the gender wise customer counts
customers['gender'].value_counts()
# Out:
# gender
# F    50
# M    50
# Name: count, dtype: int64

# %%
customers.head()
# Out:
#    customer_id  customer_name gender  age              city   join_date
# 0          201   Ashley Silva      F   47   Lake Edwardfort  2021-01-19
# 1          202  Ethan Shannon      F   55        Jaredshire  2021-05-10
# 2          203  Colleen Lopez      M   31        South Eric  2023-07-18
# 3          204   Sarah Nguyen      F   52  South Wendyhaven  2020-01-23
# 4          205      Eric Ruiz      M   61        North Mark  2020-05-19

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_id        300 non-null    int64
#  1   product_id     300 non-null    int64
#  2   customer_id    300 non-null    int64
#  3   quantity_sold  300 non-null    int64
#  4   sale_amount    300 non-null    object
#  5   sale_date      300 non-null    object
#  6   region         300 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 16.5+ KB

# %%
# converting the sales_amount column to float
sales['sale_amount'] = sales['sale_amount'].astype(float)

# %%
# checking the data types of all columns
sales.dtypes
# Out:
# sale_id            int64
# product_id         int64
# customer_id        int64
# quantity_sold      int64
# sale_amount      float64
# sale_date         object
# region            object
# dtype: object

# %%
sales.head()
# Out:
#    sale_id  product_id  customer_id  quantity_sold  sale_amount   sale_date  \
# 0        1         107          273              5       1000.0  2024-09-01
# 1        2         104          212              7        700.0  2024-05-31
# 2        3         107          223              2        400.0  2024-03-19
# 3        4         103          288              1        240.0  2024-02-21
# 4        5         112          274              6        600.0  2024-05-05
#
#   region
# 0  South
# 1   West
# 2   West
# 3   West
# 4   West

# %%
products.head(7)
# Out:
#    product_id  product_name     category  price
# 0         101        Laptop  Electronics  250.0
# 1         102    Smartphone  Electronics  300.0
# 2         103        Tablet  Electronics  240.0
# 3         104    Headphones  Electronics  100.0
# 4         105  Office Chair    Furniture  400.0
# 5         106          Desk    Furniture  350.0
# 6         107     Bookshelf    Furniture  200.0

# %%
# merging sales with products based on product_id
sales_products = sales.merge(products, on = 'product_id', how = 'inner')

# %%
sales_products
# Out:
#      sale_id  product_id  customer_id  quantity_sold  sale_amount   sale_date  \
# 0          1         107          273              5       1000.0  2024-09-01
# 1          3         107          223              2        400.0  2024-03-19
# 2          8         107          297              9       1800.0  2024-03-12
# 3         17         107          294              7       1400.0  2024-05-10
# 4         30         107          298              1        200.0  2024-11-06
# ..       ...         ...          ...            ...          ...         ...
# 295      138         109          209              8        160.0  2024-06-12
# 296      143         109          218             10        200.0  2024-10-05
# 297      150         109          204              5        100.0  2024-10-13
# 298      247         109          287              9        180.0  2024-03-17
# 299      257         109          207             10        200.0  2024-09-12
#
# ...

# %%
# adding a new column to show total sale-amount
sales_products['total_sale_amount'] = sales_products['price'] * sales_products['quantity_sold']

# %%
sales_products
# Out:
#      sale_id  product_id  customer_id  quantity_sold  sale_amount   sale_date  \
# 0          1         107          273              5       1000.0  2024-09-01
# 1          3         107          223              2        400.0  2024-03-19
# 2          8         107          297              9       1800.0  2024-03-12
# 3         17         107          294              7       1400.0  2024-05-10
# 4         30         107          298              1        200.0  2024-11-06
# ..       ...         ...          ...            ...          ...         ...
# 295      138         109          209              8        160.0  2024-06-12
# 296      143         109          218             10        200.0  2024-10-05
# 297      150         109          204              5        100.0  2024-10-13
# 298      247         109          287              9        180.0  2024-03-17
# 299      257         109          207             10        200.0  2024-09-12
#
# ...

# %%
customers.head()
# Out:
#    customer_id  customer_name gender  age              city   join_date
# 0          201   Ashley Silva      F   47   Lake Edwardfort  2021-01-19
# 1          202  Ethan Shannon      F   55        Jaredshire  2021-05-10
# 2          203  Colleen Lopez      M   31        South Eric  2023-07-18
# 3          204   Sarah Nguyen      F   52  South Wendyhaven  2020-01-23
# 4          205      Eric Ruiz      M   61        North Mark  2020-05-19

# %%
# exporting customers data to an excel file
customers.to_excel('Customers.xlsx', index = False)

# %%
# exporting merged sales_products data to an excel file
sales_products.to_excel('Sales_Products.xlsx', index = False)
